# %% [markdown]
# ##          Project-Movie Recommendation System

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## PART 1: Get The Dataset

# %% [markdown]
# ### Step1: Importing Libraries

# %% [raw]
# - Importing necessary libraries like numpy,pandas,warnings and aliasing them as np,pd etc for our convenience.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step2: Loading a dataset

# %% [raw]
# Got this data from the below website.
# Website:"https://grouplens.org/datasets/movielens/100k/"
#
# - Firstly going with the general description about the data.
#
# - use 'pd' everytime for working with pandas.
#
# - loading the data by using read_csv() with the location path and separator i.e. is using sep='\t' since data is not a csv file ,it is tab separated data .
#
# - Here there is no Header,so we need to define header as a list i.e.column_names=['user_id','item_id','rating','timestamp']

# %%
column_names=['user_id','item_id','rating','timestamp']
df= pd.read_csv("/content/drive/MyDrive/Movie Recommendation System/ml-100k/u.data",sep='\t',names=column_names)

# %% [markdown]
# ### Step3: Know about the Data

# %% [raw]
# - Here we created a 'df' dataframe
#
# - head(): gives top rows and we pass number of rows as an argument.Stores data            as table
#
# - shape: gives number of rows and columns.Stores data as a tuple object.                (100000, 5) which inlcudes the row header
#
# - nunique(): gives the total number of unique values for a particular column.
#             total user_id's=943  refers to person who rated a movie
#             total item_id's=1682 refers to movie title

# %%
print(df.head())
print(df.shape)
print(df['user_id'].nunique())
print(df['item_id'].nunique())
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596
# (100000, 4)
# 943
# 1682

# %% [raw]
# - By studying the above dataframe 'df', it is data is spread out to 1 lakh records over 5 columns.
# - when we find unique user_id's they are very less i.e 943.
# - For every movie there will be particular item_id,there are total of 1682 movies.
# - It is better if we can see all the movie names.

# %% [markdown]
# ### Step 4: Get the reduced movie title dataset

# %% [raw]
# - loading the data by using read_csv() with the location path and separator i.e. is using sep='\|' since data is not a csv file ,it is pipe separated data .
#
# - the shape of movies_titles dataset is (1682,24) which clearly matches with total number of item_id's but contains other columns too.
#
# - Reducing the dataset movies_titles by taking required index columns [0,1]
# and reassigning to the same dataset.There is no header so adding header columns as ['item_id','title']

# %%
movies_titles=pd.read_csv('/content/drive/MyDrive/Movie Recommendation System/ml-100k/u.item',sep='\|',header=None)
print(movies_titles.shape)
#print(movies_titles.head())
movies_titles=movies_titles[[0,1]]
movies_titles.columns=['item_id','title']
print(movies_titles.head())
# Out:
# (1682, 24)
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %% [markdown]
# ### Step 5: Merge df and movies_title dataset  on='item_id'

# %% [raw]
# - using merge() funtion for  df and movies_title dataset with common column  ****on='item_id****   and reassinging to 'df'.
# - using tail() function to see the bottom records

# %%
df=pd.merge(df,movies_titles,on='item_id')
df.tail()
# Out:
#        user_id  ...                                              title
# 99995      840  ...                                  Mamma Roma (1962)
# 99996      655  ...                             Eighth Day, The (1996)
# 99997      655  ...                                  Girls Town (1996)
# 99998      655  ...  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999      655  ...                                    Dadetown (1995)
#
# [5 rows x 5 columns]

# %%
###########################################################################

# %%
###########################################################################

# %% [markdown]
# ## PART 2: Exploratory Data Analysis

# %% [markdown]
# ### Step 6: Importing Visualization Libraries

# %% [raw]
# # Firstly importing the necessary libraries like matplotlib.pyplot ,seaborn as plt and sns respectively.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %% [markdown]
# ### Step 7: Grouping and Sorting

# %% [raw]
# - In movie recommendation ,title plays a key role.
# - If particular movie title is given as input,then similar movies will get   reflected.
#
# - Using groupby() on title column and there is requirement of any other attribute which helps in grouping this title names of movies.
#
# - Using mean() for the ratings so then grouping of the titles can takesplace.
# - Thereafter Using the sort_values() and passing asecending=False arg.
# - Thus it gives insight that rating '5' is 100% value which needed to checked since it  effects the remaining ratings.
#
# - So groupby() is performed with respect to count() of the ratings.
# and then sort_values() should be done.
# - This gives an insight of frequency or total number of people rated 5 star or any other rating for a particular movie.

# %%
print(df.groupby('title').mean()['rating'].sort_values(ascending=False).head())

print(df.groupby('title').count()['rating'].sort_values(ascending=False))
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64
# title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# � k�ldum klaka (Cold Fever) (1994)              1
# Name: rating, Length: 1664, dtype: int64

# %% [markdown]
# ### Step 8: Creating a 'rating' DataFrame of groupby data

# %% [raw]
# - A ratings dataframe is produced out of groupby data according to mean and count.
# - This can be done by producing a dataframe by using groupby data with respect to mean.
# And thereafter,assigning a new column i.e. 'num of ratings' with groupby data with respect to count.
#
# - Finally sorting the ratings and using describe().

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['rating'])
print(ratings)

ratings['num of ratings']=df.groupby('title').count()['rating']
print(ratings)

print(ratings.sort_values(by='rating',ascending=True).describe())
# Out:
#                                          rating
# title
# 'Til There Was You (1997)              2.333333
# 1-900 (1994)                           2.600000
# 101 Dalmatians (1996)                  2.908257
# 12 Angry Men (1957)                    4.344000
# 187 (1997)                             3.024390
# ...                                         ...
# Young Guns II (1990)                   2.772727
# Young Poisoner's Handbook, The (1995)  3.341463
# Zeus and Roxanne (1997)                2.166667
# unknown                                3.444444
# � k�ldum klaka (Cold Fever) (1994)     3.000000
#
# [1664 rows x 1 columns]
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# ...

# %% [markdown]
# ### Step 9: Plotting the Data ('num of ratings','rating')

# %% [raw]
# - Using plt library
# - Using figure(),hist() functions
# - Using figsize=(m,n),bins=number,particular column or attribute for plotting  arguments can used.
# - Using 'show' property

# %% [raw]
# - plot1 describing "num of ratings"
# Here:
# x=count(total number of ratings for a particular movie)
# y=That same number=count(number of user_id's) for different movies
#
# - example: this is a decreaing trend of y  as x value increases.
# it tells, the minimun users like 2 or 4 or 5 or 10 in number are high in        majority for different movies.
# - As x increases it means the count(total number of ratings for a particular movie) increasing and y started decreasing it means there are same count(number of user_id's) for different movies

# %%
# For "num of ratings"
plt.figure(figsize=(10,6))
plt.hist(ratings['num of ratings'],bins=70)
print(plt.show)
# Out:
# <function show at 0x7fae254085f0>

# %%
# For "rating"
plt.hist(ratings['rating'],bins=70)
print(plt.show)
# Out:
# <function show at 0x7fae254085f0>

# %% [markdown]
# ### Step 10: Using sns for Jointplot

# %% [raw]
# - Using sns library
# - Using jointplot function
# - Giving certain Arguments such as x,y labels;dataframe,alpha(#opacity)=lies between 0 to 1)
#
#
# - This plot depicts as 'rating' increases 'num of rating' also increased.
# - For starting and ending values of rating i.e. 1 and 5 star ,the num of rating count is very low  and this data should be dropped.

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=1)

# %%
#########################################################################

# %%
#########################################################################

# %% [markdown]
# ## Part 3: Creating Basis For Movie Recommendation

# %% [markdown]
# ### Step 11:Creating A Pivot_table i.e. moviemat dataframe

# %% [raw]
# - Creating a dataframe called "moviemat" by using pivot_table().
# - Here we pass certain arguments like index,columns,values.
#
# - With this a table is displayed as an output which shows majority of data is of NaN which is missing.

# %%
moviemat=df.pivot_table(index='user_id',columns='title',values='rating')
moviemat
# Out:
# title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# user_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
# ...                            ...  ...                                 ...
# 939                            NaN  ...                                 NaN
# 940                            NaN  ...                                 NaN
# 941                            NaN  ...                                 NaN
# 942                            NaN  ...                                 NaN
# 943                            NaN  ...                                 NaN
#
# ...

# %%
moviemat.head()
# Out:
# title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# user_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# ### Step 12: Performing sorting  on 'ratings' dataframe

# %% [raw]
# - After sorting the values according to 'num of ratings',we can see
# "Star Wars (1977)	4.358491	583"
# - This record has maximum num of ratings and it can be best suited for performing correlation and furtherly a function can be defined.

# %%
ratings.sort_values('num of ratings',ascending=False).head()
# Out:
#                              rating  num of ratings
# title
# Star Wars (1977)           4.358491             583
# Contact (1997)             3.803536             509
# Fargo (1996)               4.155512             508
# Return of the Jedi (1983)  4.007890             507
# Liar Liar (1997)           3.156701             485

# %% [markdown]
# ### Step 13: Performing Slicing  on 'moviemat' dataframe

# %% [raw]
# - Here we considering 'Star Wars (1977)' title which was rated by many users_id as shown belown in the output.

# %%
starwars_user_ratings=moviemat['Star Wars (1977)']
starwars_user_ratings.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %% [markdown]
# ### Step 14:Correlation of  starwars_user_ratings with all movies
# ### i.e. moviemat

# %% [raw]
# - Gives correlation between moviemat dataframe and sliced starwars_user_ratings dataframe.
# - Correlation value ranges from -1 to +1
# - more positive or negative is a good factor to be considered.
# - near to +1 are the movies which are similar and to be likely to watch.
# - near to -1 are the movies which are not similar and are contrast to the movie.

# %%
similar_to_starwars=moviemat.corrwith(starwars_user_ratings)
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# � k�ldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %% [markdown]
# ### Step15: Ultimately Working with corr_starwars dataframe

# %% [markdown]
# ### A,creating a corr_starwars dataframe

# %% [raw]
# - from previous 'similar_to_starwars' datafram creating a new dataframe with a header for correlation values.i.e. corr_starwars

# %%
corr_starwars=pd.DataFrame(similar_to_starwars,columns=['correlation'])
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
# � k�ldum klaka (Cold Fever) (1994)             NaN
#
# [1664 rows x 1 columns]

# %% [markdown]
# ### B, Dropping NaN records from the  corr_starwars dataframe

# %%
corr_starwars.dropna(inplace=True)
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.head()
# Out:
#                            correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %% [markdown]
# ### (for understanding) Sorting the corr_starwars dataframe

# %%
corr_starwars.sort_values('correlation',ascending=False).head(10)
# Out:
#                                                     correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %% [markdown]
# ### C, Adding 'num of ratings'  to corr_starwars using join() method.

# %%
corr_starwars=corr_starwars.join(ratings['num of ratings'])
corr_starwars.head(10)
# Out:
#                                      correlation  num of ratings
# title
# 'Til There Was You (1997)               0.872872               9
# 1-900 (1994)                           -0.645497               5
# 101 Dalmatians (1996)                   0.211132             109
# 12 Angry Men (1957)                     0.184289             125
# 187 (1997)                              0.027398              41
# 2 Days in the Valley (1996)             0.066654              93
# 20,000 Leagues Under the Sea (1954)     0.289768              72
# 2001: A Space Odyssey (1968)            0.230884             259
# 39 Steps, The (1935)                    0.106453              59
# 8 1/2 (1963)                           -0.142977              38

# %% [markdown]
# ### D, Taking "num of ratings" values greater than 100 and sorting correlations

# %% [raw]
# - More number of users rated a movie is necessary for good similar movie recommendation.
#
# - same number i.e count(number of user_id's) for different movies is nearly constant after the 100 or more user ratings are common for many movies

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('correlation',ascending=False)
# Out:
#                                                     correlation  num of ratings
# title
# Star Wars (1977)                                       1.000000             583
# Empire Strikes Back, The (1980)                        0.747981             367
# Return of the Jedi (1983)                              0.672556             507
# Raiders of the Lost Ark (1981)                         0.536117             420
# Austin Powers: International Man of Mystery (1997)     0.377433             130
# ...                                                         ...             ...
# Edge, The (1997)                                      -0.127167             113
# As Good As It Gets (1997)                             -0.130466             112
# Crash (1996)                                          -0.148507             128
# G.I. Jane (1997)                                      -0.176734             175
# First Wives Club, The (1996)                          -0.194496             160
#
# ...

# %% [markdown]
# ### Part 4: Defining a function for Movie Recommendation System

# %% [raw]
# - collecting finalized main important programs of "star_wars" and replace it by
# "movie_name" ;steps[13,14,15[A,B,C,D]]
#
# - what ever the movie_title ,we give to the function will return the              predictions i.e.step:15D

# %%
def predict_movies(movie_name):
    movie_user_ratings=moviemat[movie_name]#13
    similar_to_movie=moviemat.corrwith( movie_user_ratings)#14
    
    #15[A<B<C<D]
    corr_movie=pd.DataFrame(similar_to_movie,columns=['correlation'])#A
    corr_movie.dropna(inplace=True)#B
    
    corr_movie=corr_movie.join(ratings['num of ratings'])#C
    predictions=corr_movie[corr_movie['num of ratings']>100].sort_values('correlation',ascending=False)#D
    
    return predictions

# %%
movie_recomendations=predict_movies("Titanic (1997)")
movie_recomendations.head()
# Out:
#                               correlation  num of ratings
# title
# Titanic (1997)                   1.000000             350
# River Wild, The (1994)           0.497600             146
# Abyss, The (1989)                0.472103             151
# Bram Stoker's Dracula (1992)     0.443560             120
# True Lies (1994)                 0.435104             208

# %% [markdown]
# ### Note:Other recomendation projects can be done on 'Book' or 'Music'.
